# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
raw_df = pd.read_csv('data_raw/train.csv')

# %% [markdown]
# # Quick overview

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 24 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Id        256 non-null    int64
#  1   time      256 non-null    object
#  2   T_min     256 non-null    float64
#  3   T_mean    256 non-null    float64
#  4   T_max     256 non-null    float64
#  5   P_min     256 non-null    float64
#  6   P_mean    256 non-null    float64
#  7   P_max     256 non-null    float64
#  8   U_min     256 non-null    int64
#  9   U_mean    256 non-null    float64
#  10  U_max     256 non-null    int64
#  11  Ff_min    256 non-null    int64
#  12  Ff_mean   256 non-null    float64
#  13  Ff_max    256 non-null    int64
#  14  N_min     256 non-null    float64
#  15  N_mean    256 non-null    float64
#  16  N_max     256 non-null    float64
#  17  VV_min    256 non-null    float64
#  18  VV_mean   256 non-null    float64
#  19  VV_max    256 non-null    float64
#  20  RRR_min   256 non-null    float64
#  21  RRR_mean  256 non-null    float64
#  22  RRR_max   256 non-null    float64
#  23  y         256 non-null    int64
# dtypes: float64(17), int64(6), object(1)
# memory usage: 48.1+ KB

# %%
raw_df.describe().T
# Out:
#           count        mean        std        min         25%        50%
# Id        256.0  127.500000  74.045031    0.00000   63.750000  127.50000  \
# T_min     256.0    5.837500   9.746899  -22.00000    0.300000    6.00000
# T_mean    256.0    9.078460  10.471138  -17.62500    3.200000    8.76875
# T_max     256.0   12.396484  11.400748  -13.50000    5.400000   12.10000
# P_min     256.0  759.494141   7.318106  736.60000  755.475000  759.40000
# P_mean    256.0  761.444817   6.964801  741.26250  757.331250  761.25000
# P_max     256.0  763.418359   6.493497  746.00000  759.000000  763.35000
# U_min     256.0   56.753906  18.904040   17.00000   40.000000   58.00000
# U_mean    256.0   71.619350  14.402558   35.87500   61.843750   73.43750
# U_max     256.0   85.484375  10.216084   50.00000   81.000000   88.50000
# Ff_min    256.0    2.781250   1.583927    0.00000    2.000000    2.00000
# Ff_mean   256.0    4.610631   1.599353    1.25000    3.468750    4.50000
# Ff_max    256.0    6.589844   2.076888    3.00000    5.000000    6.00000
# N_min     256.0    0.435742   0.320725    0.00000    0.250000    0.40000
# N_mean    256.0    0.692024   0.256392    0.00625    0.531250    0.73750
# N_max     256.0    0.875586   0.213192    0.05000    0.750000    1.00000
# VV_min    256.0    6.961328   3.583999    0.10000    3.400000   10.00000
# VV_mean   256.0    9.000954   1.600084    2.25000    8.546875   10.00000
# VV_max    256.0    9.920703   0.626726    3.60000   10.000000   10.00000
# RRR_min   256.0    0.284961   0.838672    0.00000    0.000000    0.00000
# RRR_mean  256.0    0.928711   1.967577    0.00000    0.000000    0.12500
# RRR_max   256.0    1.572461   3.512333    0.00000    0.000000    0.20000
# y         256.0    0.695312   0.461177    0.00000    0.000000    1.00000
#
#                  75%       max
# Id        191.250000  255.0000
# T_min      13.700000   23.5000
# T_mean     17.331250   29.0000
# T_max      21.600000   33.2000
# P_min     763.925000  781.3000
# P_mean    765.640625  782.6375
# P_max     767.200000  784.0000
# U_min      73.000000   94.0000
# U_mean     83.156250   94.8750
# U_max      93.000000   98.0000
# Ff_min      4.000000    8.0000
# Ff_mean     5.750000   10.0000
# Ff_max      8.000000   13.0000
# N_min       0.600000    1.0000
# N_mean      0.901563    1.0000
# N_max       1.000000    1.0000
# VV_min     10.000000   10.0000
# VV_mean    10.000000   10.0000
# VV_max     10.000000   10.0000
# RRR_min     0.050000    6.0000
# RRR_mean    1.006250   17.5000
# RRR_max     2.000000   30.0000
# y           1.000000    1.0000

# %%
profile = ProfileReport(raw_df)
profile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# # FAAFO
